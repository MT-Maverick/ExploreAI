# %%
import pandas as pd 
import numpy as np 
from weather_analysis.loader import load_data, rename_cols
from weather_analysis.stats import *
from weather_analysis.visualization import *

file_path = 'chart.csv'

# %%
df = load_data(file_path)

# %%
df = rename_cols(df)
# Out:
# Current columns:
#   Category  Average Minimum Surface Air Temperature  \
# 0      Jan                                    18.87
# 1      Feb                                    19.35
# 2      Mar                                    20.26
# 3      Apr                                    20.56
# 4      May                                    19.78
#
#    Average Mean Surface Air Temperature  \
# 0                                 25.47
# 1                                 26.18
# 2                                 26.65
# 3                                 26.05
# 4                                 25.02
#
#    Average Maximum Surface Air Temperature  Precipitation
# 0                                    32.12          31.75
# 1                                    33.06          25.41
# 2                                    33.09          63.26
# 3                                    31.58         135.18
# 4                                    30.31          92.13
# Updated column names:
# ...

# %%
print_summary(df)
# Out:
# Data Summary:
#         min_temp  mean_temp   max_temp  Precipitation
# count  12.000000  12.000000  12.000000      12.000000
# mean   19.175833  25.012500  30.898333      60.318333
# std     0.780902   1.003912   1.402380      36.469570
# min    18.020000  23.340000  28.710000      25.410000
# 25%    18.580000  24.367500  30.092500      31.662500
# 50%    19.145000  25.040000  30.770000      47.405000
# 75%    19.600000  25.615000  31.715000      80.497500
# max    20.560000  26.650000  33.090000     135.180000

# %%
column_stats(df, "mean_temp")
# Out:
# {'mean': 25.0125, 'median': 25.04, 'std_dev': 0.9611722443627537}

# %%
get_highest_precipitation_month(df)
# Out:
# 'Apr'

# %%
visualize_precipitation(df)

# %%
visualize_temps(df)
